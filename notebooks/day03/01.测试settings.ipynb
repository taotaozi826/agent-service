# %% [markdown]
# pydantic settings 测试

# %%
from app.core.config import settings

# print(settings)

print(settings.model_dump())

print(settings.model_dump_json(indent=4))
# Out:
# {'app': {'name': '安心保', 'host': '0.0.0.0', 'port': 8001, 'debug': True}, 'db': {'host': '192.168.150.101', 'port': 5432, 'name': 'insurance', 'user': 'insurance', 'password': 'insurance123', 'url': 'postgresql+asyncpg://insurance:insurance123@192.168.150.101:5432'}, 'llm': {'api_key': 'sk-9f5db1f76ff742758fc581e641213839', 'chat_model': 'deepseek-v4-pro'}, 'logging': {'level': 'INFO'}}
# {
#     "app": {
#         "name": "安心保",
#         "host": "0.0.0.0",
#         "port": 8001,
#         "debug": true
#     },
#     "db": {
#         "host": "192.168.150.101",
#         "port": 5432,
#         "name": "insurance",
#         "user": "insurance",
#         "password": "insurance123",
#         "url": "postgresql+asyncpg://insurance:insurance123@192.168.150.101:5432"
#     },
#     "llm": {
#         "api_key": "sk-9f5db1f76ff742758fc581e641213839",
#         "chat_model": "deepseek-v4-pro"
#     },
#     "logging": {
#         "level": "INFO"
#     }
# }
