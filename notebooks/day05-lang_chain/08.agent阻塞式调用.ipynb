# %%
# invoke调用Agent
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# 1.加载环境变量
load_dotenv()

# 2.初始化模型
model = init_chat_model(
        "deepseek-v4-flash",
        extra_body={"thinking": {"type": "disabled"}}
    )

# 3.定义tool（可以没有，不过这个时候只能对话，不算完整的Agent）
tools=[]

# 4.创建智能体
agent = create_agent(
    model = model,
    tools=tools
)

# 5.调用Agent
response = agent.invoke({
    "messages": [HumanMessage("你是谁？")]
})
print(response)
print('*' * 50)
print(response['messages'])
print('*' * 50)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='你是谁？', additional_kwargs={}, response_metadata={}, id='afd94be4-5ed9-40bd-8d1f-a6f72d069740'), AIMessage(content='你好呀！我是DeepSeek，由深度求索公司创造的AI助手。😊\n\n简单介绍一下自己：\n- **免费使用**：目前完全免费，无需付费\n- **强大能力**：支持100万token的超长上下文，可以一次性处理像《三体》三部曲那样的长篇内容\n- **多种功能**：支持文件上传（图片、PDF、Word、Excel等），可以从中提取文字信息处理；支持联网搜索（需要手动开启）；App端还支持语音输入\n- **知识更新**：知识截止到2025年5月\n\n我的使命就是热情、细腻地帮助你解决各种问题，无论是学习、工作还是生活上的困惑，都可以随时问我！\n\n有什么我可以帮你的吗？尽管说，我会竭尽全力为你提供帮助！✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 163, 'prompt_tokens': 6, 'total_tokens': 169, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'c1d20bfd-3d4e-40cb-acab-e071e7dd43a0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0472f-c26b-7a92-8527-f39d3eaef366-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 163, 'total_tokens': 169, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# **************************************************
# [HumanMessage(content='你是谁？', additional_kwargs={}, response_metadata={}, id='afd94be4-5ed9-40bd-8d1f-a6f72d069740'), AIMessage(content='你好呀！我是DeepSeek，由深度求索公司创造的AI助手。😊\n\n简单介绍一下自己：\n- **免费使用**：目前完全免费，无需付费\n- **强大能力**：支持100万token的超长上下文，可以一次性处理像《三体》三部曲那样的长篇内容\n- **多种功能**：支持文件上传（图片、PDF、Word、Excel等），可以从中提取文字信息处理；支持联网搜索（需要手动开启）；App端还支持语音输入\n- **知识更新**：知识截止到2025年5月\n\n我的使命就是热情、细腻地帮助你解决各种问题，无论是学习、工作还是生活上的困惑，都可以随时问我！\n\n有什么我可以帮你的吗？尽管说，我会竭尽全力为你提供帮助！✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 163, 'prompt_tokens': 6, 'total_tokens': 169, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': 'c1d20bfd-3d4e-40cb-acab-e071e7dd43a0', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0472f-c26b-7a92-8527-f39d3eaef366-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 163, 'total_tokens': 169, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]
# **************************************************
# 你好呀！我是DeepSeek，由深度求索公司创造的AI助手。😊
#
# 简单介绍一下自己：
# - **免费使用**：目前完全免费，无需付费
# - **强大能力**：支持100万token的超长上下文，可以一次性处理像《三体》三部曲那样的长篇内容
# - **多种功能**：支持文件上传（图片、PDF、Word、Excel等），可以从中提取文字信息处理；支持联网搜索（需要手动开启）；App端还支持语音输入
# - **知识更新**：知识截止到2025年5月
#
# 我的使命就是热情、细腻地帮助你解决各种问题，无论是学习、工作还是生活上的困惑，都可以随时问我！
#
# 有什么我可以帮你的吗？尽管说，我会竭尽全力为你提供帮助！✨
