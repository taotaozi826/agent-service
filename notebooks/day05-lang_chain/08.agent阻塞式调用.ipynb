# %%
# invoke调用Agent
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# 1.加载环境变量
load_dotenv()

# 2.初始化模型
model = init_chat_model(
        "deepseek-v4-flash",
        extra_body={"thinking": {"type": "disabled"}}
    )

# 3.定义tool（可以没有，不过这个时候只能对话，不算完整的Agent）
tools=[]

# 4.创建智能体
agent = create_agent(
    model = model,
    tools=tools
)

# 5.调用Agent
response = agent.invoke({
    "messages": [HumanMessage("你是谁？")]
})
print(response)
print('*' * 50)
print(response['messages'])
print('*' * 50)
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='你是谁？', additional_kwargs={}, response_metadata={}, id='6f8aab9d-9244-442e-a3bb-30d8252f03d3'), AIMessage(content='嗨！很高兴认识你！👋\n\n我是**DeepSeek**，由深度求索公司创造的AI助手。我是最新版的DeepSeek模型，专门为你提供帮助而设计。\n\n**关于我的一些特点：**\n- 📚 **知识丰富**：我的知识截止到2025年5月\n- 💬 **纯文本模型**：擅长文字交流，支持阅读链接\n- 📎 **文件处理**：可以上传图片、PDF、Word、Excel等文件，我会读取其中的文字信息\n- 🌐 **联网搜索**：支持联网查询（需要你在Web/App端手动开启）\n- 🆓 **完全免费**：没有任何收费计划！\n- 🎯 **超长上下文**：1M的上下文窗口，能一次性处理像《三体》三部曲那么大的内容\n\n你可以用我来做很多事情：回答问题、写作、编程、翻译、头脑风暴…… 几乎任何需要文字处理的任务！\n\n有什么我可以帮助你的吗？尽管问，我会全力以赴！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 211, 'prompt_tokens': 6, 'total_tokens': 217, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '69d5c290-f355-4938-aeb4-a6c79f1b6f0e', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a057d5-4720-70d2-87de-866827155fb4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 211, 'total_tokens': 217, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
# **************************************************
# [HumanMessage(content='你是谁？', additional_kwargs={}, response_metadata={}, id='6f8aab9d-9244-442e-a3bb-30d8252f03d3'), AIMessage(content='嗨！很高兴认识你！👋\n\n我是**DeepSeek**，由深度求索公司创造的AI助手。我是最新版的DeepSeek模型，专门为你提供帮助而设计。\n\n**关于我的一些特点：**\n- 📚 **知识丰富**：我的知识截止到2025年5月\n- 💬 **纯文本模型**：擅长文字交流，支持阅读链接\n- 📎 **文件处理**：可以上传图片、PDF、Word、Excel等文件，我会读取其中的文字信息\n- 🌐 **联网搜索**：支持联网查询（需要你在Web/App端手动开启）\n- 🆓 **完全免费**：没有任何收费计划！\n- 🎯 **超长上下文**：1M的上下文窗口，能一次性处理像《三体》三部曲那么大的内容\n\n你可以用我来做很多事情：回答问题、写作、编程、翻译、头脑风暴…… 几乎任何需要文字处理的任务！\n\n有什么我可以帮助你的吗？尽管问，我会全力以赴！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 211, 'prompt_tokens': 6, 'total_tokens': 217, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'a26a7955944dc5c60445bff77fac9c8e', 'id': '69d5c290-f355-4938-aeb4-a6c79f1b6f0e', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a057d5-4720-70d2-87de-866827155fb4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 211, 'total_tokens': 217, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]
# **************************************************
# 嗨！很高兴认识你！👋
#
# 我是**DeepSeek**，由深度求索公司创造的AI助手。我是最新版的DeepSeek模型，专门为你提供帮助而设计。
#
# **关于我的一些特点：**
# - 📚 **知识丰富**：我的知识截止到2025年5月
# - 💬 **纯文本模型**：擅长文字交流，支持阅读链接
# - 📎 **文件处理**：可以上传图片、PDF、Word、Excel等文件，我会读取其中的文字信息
# - 🌐 **联网搜索**：支持联网查询（需要你在Web/App端手动开启）
# - 🆓 **完全免费**：没有任何收费计划！
# - 🎯 **超长上下文**：1M的上下文窗口，能一次性处理像《三体》三部曲那么大的内容
#
# 你可以用我来做很多事情：回答问题、写作、编程、翻译、头脑风暴…… 几乎任何需要文字处理的任务！
#
# 有什么我可以帮助你的吗？尽管问，我会全力以赴！😊
